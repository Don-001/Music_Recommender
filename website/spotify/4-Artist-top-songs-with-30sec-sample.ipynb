# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import os
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
client_id = os.getenv("client_id")
client_secret = os.getenv("client_secret")
#SPOTIPY_REDIRECT_URI='your-app-redirect-url'

# %%
auth_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(auth_manager=auth_manager)

# %%
artist_name = 'Led Zeppelin'

# %% [markdown]
# # Searching Artist

# %%
artists = sp.search(q='artist:'+artist_name,type='artist', limit=10)

# %%
artists
# Out:
# {'artists': {'href': 'https://api.spotify.com/v1/search?query=artist%3ALed+Zeppelin&type=artist&offset=0&limit=10',
#   'items': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/36QJpDe2go2KgaRleHCDTp'},
#     'followers': {'href': None, 'total': 13184536},
#     'genres': ['album rock', 'classic rock', 'hard rock', 'rock'],
#     'href': 'https://api.spotify.com/v1/artists/36QJpDe2go2KgaRleHCDTp',
#     'id': '36QJpDe2go2KgaRleHCDTp',
#     'images': [{'height': 600,
#       'url': 'https://i.scdn.co/image/207803ce008388d3427a685254f9de6a8f61dc2e',
#       'width': 600},
#      {'height': 200,
#       'url': 'https://i.scdn.co/image/b0248a44865493e6a03832aa89854ada16ff07a8',
#       'width': 200},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/16eb3cdae0d824b520ac17710e943a99d3ef6602',
#       'width': 64}],
#     'name': 'Led Zeppelin',
#     'popularity': 79,
#     'type': 'artist',
#     'uri': 'spotify:artist:36QJpDe2go2KgaRleHCDTp'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/0xNrQovaLnM8VBUgMb3wlA'},
#     'followers': {'href': None, 'total': 1555},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/0xNrQovaLnM8VBUgMb3wlA',
#     'id': '0xNrQovaLnM8VBUgMb3wlA',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5eb7a5c39def11a195badd5c776',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab676161000051747a5c39def11a195badd5c776',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f1787a5c39def11a195badd5c776',
#       'width': 160}],
#     'name': 'In The Light of Led Zeppelin',
#     'popularity': 3,
#     'type': 'artist',
#     'uri': 'spotify:artist:0xNrQovaLnM8VBUgMb3wlA'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/6ChaTST0oG5o9vOsdsKydL'},
#     'followers': {'href': None, 'total': 0},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/6ChaTST0oG5o9vOsdsKydL',
#     'id': '6ChaTST0oG5o9vOsdsKydL',
#     'images': [],
#     'name': 'karaoke - Led Zeppelin',
#     'popularity': 0,
#     'type': 'artist',
#     'uri': 'spotify:artist:6ChaTST0oG5o9vOsdsKydL'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/2Rh2QaSt4mtaaIoUatPAXP'},
#     'followers': {'href': None, 'total': 266},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/2Rh2QaSt4mtaaIoUatPAXP',
#     'id': '2Rh2QaSt4mtaaIoUatPAXP',
#     'images': [],
#     'name': 'Led Zeppelin Jam',
#     'popularity': 0,
#     'type': 'artist',
#     'uri': 'spotify:artist:2Rh2QaSt4mtaaIoUatPAXP'}],
#   'limit': 10,
#   'next': None,
#   'offset': 0,
#   'previous': None,
#   'total': 4}}

# %%
artists['artists']['items']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/36QJpDe2go2KgaRleHCDTp'},
#   'followers': {'href': None, 'total': 13184536},
#   'genres': ['album rock', 'classic rock', 'hard rock', 'rock'],
#   'href': 'https://api.spotify.com/v1/artists/36QJpDe2go2KgaRleHCDTp',
#   'id': '36QJpDe2go2KgaRleHCDTp',
#   'images': [{'height': 600,
#     'url': 'https://i.scdn.co/image/207803ce008388d3427a685254f9de6a8f61dc2e',
#     'width': 600},
#    {'height': 200,
#     'url': 'https://i.scdn.co/image/b0248a44865493e6a03832aa89854ada16ff07a8',
#     'width': 200},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/16eb3cdae0d824b520ac17710e943a99d3ef6602',
#     'width': 64}],
#   'name': 'Led Zeppelin',
#   'popularity': 79,
#   'type': 'artist',
#   'uri': 'spotify:artist:36QJpDe2go2KgaRleHCDTp'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/0xNrQovaLnM8VBUgMb3wlA'},
#   'followers': {'href': None, 'total': 1555},
#   'genres': [],
#   'href': 'https://api.spotify.com/v1/artists/0xNrQovaLnM8VBUgMb3wlA',
#   'id': '0xNrQovaLnM8VBUgMb3wlA',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eb7a5c39def11a195badd5c776',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab676161000051747a5c39def11a195badd5c776',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f1787a5c39def11a195badd5c776',
#     'width': 160}],
#   'name': 'In The Light of Led Zeppelin',
#   'popularity': 3,
#   'type': 'artist',
#   'uri': 'spotify:artist:0xNrQovaLnM8VBUgMb3wlA'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/6ChaTST0oG5o9vOsdsKydL'},
#   'followers': {'href': None, 'total': 0},
#   'genres': [],
#   'href': 'https://api.spotify.com/v1/artists/6ChaTST0oG5o9vOsdsKydL',
#   'id': '6ChaTST0oG5o9vOsdsKydL',
#   'images': [],
#   'name': 'karaoke - Led Zeppelin',
#   'popularity': 0,
#   'type': 'artist',
#   'uri': 'spotify:artist:6ChaTST0oG5o9vOsdsKydL'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/2Rh2QaSt4mtaaIoUatPAXP'},
#   'followers': {'href': None, 'total': 266},
#   'genres': [],
#   'href': 'https://api.spotify.com/v1/artists/2Rh2QaSt4mtaaIoUatPAXP',
#   'id': '2Rh2QaSt4mtaaIoUatPAXP',
#   'images': [],
#   'name': 'Led Zeppelin Jam',
#   'popularity': 0,
#   'type': 'artist',
#   'uri': 'spotify:artist:2Rh2QaSt4mtaaIoUatPAXP'}]

# %%
artists['artists']['items'][0]
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/36QJpDe2go2KgaRleHCDTp'},
#  'followers': {'href': None, 'total': 13184536},
#  'genres': ['album rock', 'classic rock', 'hard rock', 'rock'],
#  'href': 'https://api.spotify.com/v1/artists/36QJpDe2go2KgaRleHCDTp',
#  'id': '36QJpDe2go2KgaRleHCDTp',
#  'images': [{'height': 600,
#    'url': 'https://i.scdn.co/image/207803ce008388d3427a685254f9de6a8f61dc2e',
#    'width': 600},
#   {'height': 200,
#    'url': 'https://i.scdn.co/image/b0248a44865493e6a03832aa89854ada16ff07a8',
#    'width': 200},
#   {'height': 64,
#    'url': 'https://i.scdn.co/image/16eb3cdae0d824b520ac17710e943a99d3ef6602',
#    'width': 64}],
#  'name': 'Led Zeppelin',
#  'popularity': 79,
#  'type': 'artist',
#  'uri': 'spotify:artist:36QJpDe2go2KgaRleHCDTp'}

# %%
artist_uri = artists['artists']['items'][0]['uri']
print(artist_uri)
# Out:
# spotify:artist:36QJpDe2go2KgaRleHCDTp

# %%
results = sp.artist_top_tracks(artist_uri)

for track in results['tracks'][:10]:
    print('track    : ' + track['name'])
    if track['preview_url'] is not None:
        print('audio    : ' + track['preview_url'])
    print('cover art: ' + track['album']['images'][0]['url'])
    print()
# Out:
# track    : Stairway to Heaven - Remaster
# audio    : https://p.scdn.co/mp3-preview/337c8d45ac66899bc2db9ef3ed9438fe1d035ab1?cid=4e432f0e2c9a4e85a99789f1d37acf26
# cover art: https://i.scdn.co/image/ab67616d0000b273c8a11e48c91a982d086afc69
#
# track    : Immigrant Song - Remaster
# audio    : https://p.scdn.co/mp3-preview/f50f3416ea0807503e172ba87a92d8047d4f95da?cid=4e432f0e2c9a4e85a99789f1d37acf26
# cover art: https://i.scdn.co/image/ab67616d0000b27390a50cfe99a4c19ff3cbfbdb
#
# track    : Whole Lotta Love - 1990 Remaster
# audio    : https://p.scdn.co/mp3-preview/89f3dc45265602fa874c23d638538af0f2c6b56a?cid=4e432f0e2c9a4e85a99789f1d37acf26
# cover art: https://i.scdn.co/image/ab67616d0000b273fc4f17340773c6c3579fea0d
#
# track    : Black Dog - Remaster
# audio    : https://p.scdn.co/mp3-preview/78dd352fdbe8d2a867b72c5a71ac44ef6a462ab4?cid=4e432f0e2c9a4e85a99789f1d37acf26
# cover art: https://i.scdn.co/image/ab67616d0000b273c8a11e48c91a982d086afc69
#
# track    : Rock and Roll - Remaster
# audio    : https://p.scdn.co/mp3-preview/9464a064068943a58f673035d9ebe58e98f46bea?cid=4e432f0e2c9a4e85a99789f1d37acf26
# cover art: https://i.scdn.co/image/ab67616d0000b273c8a11e48c91a982d086afc69
#
# track    : Ramble On - 1990 Remaster
# audio    : https://p.scdn.co/mp3-preview/e734d4e4f125ff5fbe7d69faa7d505dc744fb7bb?cid=4e432f0e2c9a4e85a99789f1d37acf26
# cover art: https://i.scdn.co/image/ab67616d0000b273fc4f17340773c6c3579fea0d
#
# track    : Good Times Bad Times - 1993 Remaster
# audio    : https://p.scdn.co/mp3-preview/499f6278a140080d3218c448448d0eb149eb65b7?cid=4e432f0e2c9a4e85a99789f1d37acf26
# cover art: https://i.scdn.co/image/ab67616d0000b2736f2f499c1df1f210c9b34b32
#
# track    : Going to California - Remaster
# audio    : https://p.scdn.co/mp3-preview/8c2452c1db9c3a7aad2b826cb52303a689814f6e?cid=4e432f0e2c9a4e85a99789f1d37acf26
# cover art: https://i.scdn.co/image/ab67616d0000b273c8a11e48c91a982d086afc69
#
# track    : Kashmir - Remaster
# audio    : https://p.scdn.co/mp3-preview/4d9bde799eec8913e53c184c45b9fd575690b917?cid=4e432f0e2c9a4e85a99789f1d37acf26
# cover art: https://i.scdn.co/image/ab67616d0000b273765b0617b572bdd1dbdc7d8e
#
# track    : D'yer Mak'er - Remaster
# audio    : https://p.scdn.co/mp3-preview/700f486c6cf236b102120c8e55472748c1dc7b7c?cid=4e432f0e2c9a4e85a99789f1d37acf26
# cover art: https://i.scdn.co/image/ab67616d0000b2731816adce1d49e35d3ce9a1d1

# %%
results['tracks'][9]['preview_url']
# Out:
# 'https://p.scdn.co/mp3-preview/700f486c6cf236b102120c8e55472748c1dc7b7c?cid=4e432f0e2c9a4e85a99789f1d37acf26'

# %%
from IPython.display import Audio

# %%
Audio(url=results['tracks'][9]['preview_url']+'.mp3', autoplay=False, embed=True)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
